# %%
import shutil
outdir = './output'
shutil.rmtree(outdir)

# %% [markdown]
# **Improve your business vision**

# %%
vision = """

"""

additional_prompt = ""

# %%
import os
outdir = './output'
if not os.path.exists(outdir):
    os.mkdir(outdir)

# %%
import pandas as pd
from importlib import reload

import lib.refine_vision as this
reload(this)

res = this.chain.invoke({"vision": vision, "additional_prompt":additional_prompt})
vision = {"vision": res.content.replace("\n", "")}
pd.DataFrame([vision]).to_csv('./output/vision.csv',index=False)

# %%
print(res.content)
# Out:
# Vision:
#
# "To be the beacon of innovation and progress, transforming industries and enhancing lives by pioneering solutions that redefine the boundaries of what is possible. We aim to inspire a future where our company stands synonymous with the empowerment of individuals and communities, fostering a world where every action we take moves us closer to a more sustainable, equitable, and vibrant society."
#
# Mission:
#
# "Our mission is to deliver exceptional value through cutting-edge products and services that address the ever-evolving needs of our customers. We are dedicated to relentless innovation, uncompromising quality, and fostering collaborative relationships that empower our clients and stakeholders. Every day, we strive to make a meaningful impact by being the catalyst for growth and success in every market we serve."

# %% [markdown]
# **Discovery of Main Jobs and Job Performers**

# %%
additional_prompt = ""

# %%
import json
import pandas as pd
from importlib import reload

import lib.discover_performers_and_jobs as this
reload(this)

res = this.chain.invoke({"vision": vision, "additional_prompt": additional_prompt})
res_dict = json.loads(res.additional_kwargs['function_call']['arguments'])['performers_and_jobs_list']
performers_and_jobs = pd.DataFrame(res_dict)

performers_and_jobs.to_csv('./output/performers_and_jobs.csv',index=False)

performers_and_jobs
# Out:
#                 Job_Perfomers               Aspiration_Job  \
# 0               Entrepreneurs    Achieve market disruption
# 1              Urban Planners    Create sustainable cities
# 2                   Educators     Foster lifelong learning
# 3    Healthcare Professionals     Improve patient outcomes
# 4         Software Developers     Enhance digital security
# 5    Environmental Scientists        Combat climate change
# 6          Financial Advisors       Maximize wealth growth
# 7           Community Leaders   Strengthen community bonds
# 8                  Architects  Revolutionize living spaces
# 9  Agricultural Technologists         Ensure food security
#
#                                          Main_Job  \
# 0                Develop a groundbreaking product
# 1  Design an eco-friendly public transport system
# 2           Integrate technology in the classroom
# 3              Adopt precision medicine practices
# 4             Build robust cybersecurity software
# 5       Innovate in renewable energy technologies
# 6        Create diversified investment portfolios
# 7          Organize local empowerment initiatives
# 8                   Design smart, adaptable homes
# 9               Develop high-yield crop varieties
#
#                                           Little_Job
# 0                            Conduct market research
# 1                    Implement bike-sharing programs
# 2                Create interactive learning modules
# 3  Analyze genetic data for personalized treatmen...
# 4                      Develop encryption algorithms
# 5                 Conduct climate impact assessments
# 6                              Analyze market trends
# 7            Coordinate neighborhood clean-up events
# 8                  Incorporate sustainable materials
# 9                        Optimize irrigation systems

# %% [markdown]
# **Rate the different possible markets (aka Job_Performers + jobs) using Disciplined Enterpreneur book**

# %%
import json
import pandas as pd
from importlib import reload

import lib.score_performers_and_jobs as this
reload(this)

scores = list()
import numpy as np
list_df = np.array_split(performers_and_jobs, 5)

for dataframe in list_df:  
    res = this.chain.invoke({"vision": vision, "performers_and_jobs": dataframe, "additional_prompt": additional_prompt})
    res_dict = json.loads(res.additional_kwargs['function_call']['arguments'])["score_performers_and_jobs"]
    score = pd.DataFrame(res_dict)
    scores.append(score)

performers_score = pd.concat(scores)


columns_with_scores = performers_score.filter(like='Score', axis=1)
total_score_column = pd.Series(columns_with_scores.sum(axis=1), name='Total_Score')
performers_score.insert(1, 'Total_Score', total_score_column)
performers_score = performers_score.sort_values(by='Total_Score', ascending=False)

performers_score.to_csv('./output/performers_score.csv',index=False)


performers_score
# Out:
# /home/pbs/miniconda3/envs/design/lib/python3.11/site-packages/numpy/core/fromnumeric.py:59: FutureWarning: 'DataFrame.swapaxes' is deprecated and will be removed in a future version. Please use 'DataFrame.transpose' instead.
#   return bound(*args, **kwds)
#                 Job_Perfomers  Total_Score  \
# 0               Entrepreneurs           25
# 0         Software Developers           25
# 0          Financial Advisors           24
# 0                   Educators           23
# 1              Urban Planners           22
# 1    Environmental Scientists           22
# 1  Agricultural Technologists           22
# 1           Community Leaders           21
# 0                  Architects           21
# 1    Healthcare Professionals           20
#
#                                    Funding Viability  Funding Viability Score  \
# 0  Entrepreneurs often have access to venture cap...                        4
# 0                                               High                        5
# 0  Financial advisors typically have clients with...                        5
# 0  Educational institutions often have access to ...                        4
# 1  Urban planners often work with government budg...                        3
# 1                                           Moderate                        3
# 1  With global food security being a priority, th...                        4
# 1  Community projects often rely on grants and lo...                        2
# 0  Architects often work with clients who have su...                        4
# 1  Healthcare is a well-funded sector with signif...                        5
#
#                            Sales Force Accessibility  \
# 0  Entrepreneurs are typically hands-on and have ...
# 0                                           Moderate
# 0  Financial advisors are often accessible throug...
# 0  Educators are generally accessible through aca...
# 1  Urban planners typically have direct access to...
# 1                                           Moderate
# 1  Agricultural technologists are often part of l...
# 1  Community leaders are typically embedded in lo...
# 0  Architects are a professional group that can b...
# 1  Healthcare professionals can be reached throug...
#
#    Sales Force Accessibility Score  \
# 0                                5
# 0                                3
# 0                                4
# 0                                4
# 1                                4
# 1                                3
# 1                                3
# 1                                4
# 0                                3
# 1                                3
#
#                           Customer Value Proposition  \
# 0  Entrepreneurs aiming to achieve market disrupt...
# 0                                             Strong
# 0  The value proposition for financial advisors i...
# 0  Educators constantly seek innovative solutions...
# 1  Sustainable cities are a growing need, and urb...
# 1                                        Very Strong
# 1  High-yield crop varieties are in demand to mee...
# 1  Community leaders are driven by impact, so sol...
# 0  The push for smart, adaptable homes is strong,...
# 1  The promise of precision medicine is compellin...
#
#    Customer Value Proposition Score  \
# 0                                 5
# 0                                 5
# 0                                 5
# 0                                 5
# 1                                 4
# 1                                 5
# 1                                 5
# 1                                 5
# 0                                 4
# 1                                 4
#
#                               Whole Product Delivery  \
# 0  Entrepreneurs may need to form strategic partn...
# 0                         Feasible with partnerships
# 0  Financial advisors require comprehensive solut...
# 0  Partnerships with educational technology compa...
# 1  Urban planners usually work within a network o...
# 1                    Requires strategic partnerships
# 1  Delivering high-yield crops involves a complex...
# 1  Delivering a whole product to community leader...
# 0  Architects typically rely on a network of cont...
# 1  Collaboration with medical device companies, r...
#
#    Whole Product Delivery Score  \
# 0                             3
# 0                             4
# 0                             3
# 0                             3
# 1                             4
# 1                             3
# 1                             3
# 1                             3
# 0                             3
# 1                             2
#
#                                Competitive Landscape  \
# 0  Market disruption implies entering a space wit...
# 0                     Challenging but differentiable
# 0  The financial advisory space is competitive, b...
# 0  The educational technology market is competiti...
# 1  The field of urban planning can be competitive...
# 1                    Growing but open for innovation
# 1  The agricultural sector has established player...
# 1  While there may be competition, community lead...
# 0  The field of architecture is competitive, but ...
# 1  Healthcare is highly competitive with establis...
#
#    Competitive Landscape Score  \
# 0                            3
# 0                            3
# 0                            3
# 0                            3
# 1                            3
# 1                            4
# 1                            3
# 1                            4
# 0                            3
# 1                            3
#
#                  Market Segmentation and Scalability  \
# 0  If the product is truly disruptive, it can red...
# 0                     High potential for scalability
# 0  Success in the financial advisory market can l...
# 0  Success in one educational segment can lead to...
# 1  Success in one city can lead to opportunities ...
# 1           Good with potential for adjacent markets
# 1  Success in one crop variety can lead to opport...
# 1  Success with community leaders can open doors ...
# 0  Sustainable and smart home design has the pote...
# 1  Innovations in healthcare can expand from nich...
#
#    Market Segmentation and Scalability Score
# 0                                          5
# 0                                          5
# 0                                          4
# 0                                          4
# 1                                          4
# 1                                          4
# 1                                          4
# 1                                          3
# 0                                          4
# 1                                          3

# %% [markdown]
# **Synthesis of Job Performers**

# %%
selected_job_performers = "Educators"
selected_main_job = "Create an engaging curriculum"
number = "2"
additional_prompt   = ""

# %%
import json
import pandas as pd
from importlib import reload

import lib.generate_performers as this
reload(this)

res = this.chain.invoke({"number": number, "job_performers": selected_job_performers, "additional_prompt": additional_prompt})

performers = pd.DataFrame(json.loads(res.content)["job_performers"])
performers.to_csv('./output/performers.csv',index=False)

performers
# Out:
#                   Name                      Profession   Industry  \
# 0  Dr. Amelia Hartford  Associate Professor of Biology   Academia
# 1      Marcus Reynolds        High School Math Teacher  Education
#
#   Experience_level                                        Description
# 0     Intermediate  Dr. Amelia Hartford is an accomplished Associa...
# 1      Experienced  Marcus Reynolds is a seasoned High School Math...

# %% [markdown]
# **Automated Interviews**

# %%
import json

from importlib import reload

import lib.interview_performers as this
reload(this)

interviews = []
for index, row in performers.iterrows():
    performer = row.to_json()

    main_job_related = f"""Answer the following question focusing and thinking about the main job {selected_main_job} applied to what you are doing as {row['Profession']}.
    If the main job {selected_main_job} is not related to you, simply answer \"This is not my main job\" and skip the question."""

    # main_job_related = ""

    res = this.chain.invoke({"job_performer": performer, "main_job_related": main_job_related})
    res_dict = json.loads(res.additional_kwargs['function_call']['arguments'])
    
    interview = pd.DataFrame(res_dict["interview"])
    
    job_performer_dict = row.to_dict()

    job_performer_dict.update({"interview": interview})

    interviews.append(job_performer_dict)

# %%
import os
outdir = './output/interviews'
if not os.path.exists(outdir):
    os.mkdir(outdir)

for interview in interviews:
    interview["interview"].to_csv(
        os.path.join(outdir,"_".join((
        interview["Name"].replace(" ", ""),
        interview["Profession"].replace(" ", ""),
        interview["Industry"].replace(" ", ""),
        interview["Experience_level"].replace(" ", ""),
        ))+".csv"),
        index=False)

# %% [markdown]
# **Analyze Interviews**

# %%
import json
import pandas as pd
from importlib import reload

import lib.analyse_interviews as this
reload(this)

analysis_list = []
for interview in interviews:
    res = this.chain.invoke({"interview":interview})
    res_dict = json.loads(res.additional_kwargs['function_call']['arguments'])["analysis"]
    analysis_list.append(pd.DataFrame(res_dict))

analysis = pd.concat(analysis_list)
analysis.to_csv('./output/analysis.csv',index=False)

# %%
analysis = pd.read_csv('./output/analysis.csv')

# %%
analysis
# Out:
#                                        Quote and note  \
# 0   I begin by reviewing the existing curriculum a...
# 1   The previous step is to collect feedback from ...
# 2   After refining the curriculum, I implement it ...
# 3   Decisions are made based on a combination of s...
# 4   I wrap things up by reviewing the outcomes of ...
# 5   I start by reviewing the current curriculum, a...
# 6   The previous step is gathering data on student...
# 7   After implementing changes, I continue by coll...
# 8   My decisions are data-driven and student-cente...
# 9   I wrap things up by finalizing the curriculum,...
# 10  When time is limited, I may adapt existing res...
# 11  Accessing shared resources could be easier. A ...
# 12  I tend to avoid tasks that don't have a direct...
# 13  The most frustrating part is navigating bureau...
# 14  I adapt my approach when faced with varying le...
#
#                                              Job Step  \
# 0               Review and assess existing curriculum
# 1         Collect feedback and integrate new findings
# 2   Implement and observe curriculum in the classroom
# 3         Make decisions based on data and experience
# 4    Review outcomes and plan for future improvements
# 5                Review and assess current curriculum
# 6     Gather data on student performance and feedback
# 7   Collect feedback and monitor engagement after ...
# 8     Make data-driven and student-centered decisions
# 9   Finalize and align curriculum with standards a...
# 10  Adapt existing resources when time is constrained
# 11    Access and utilize shared educational resources
# 12  Prioritize tasks with direct impact on student...
# 13     Navigate educational bureaucracy and paperwork
# 14   Adapt teaching approach to diverse student needs
#
#                                     Emotional Aspects  \
# 0       feel excited about the potential improvements
# 1        feel confident in the curriculum's relevance
# 2              feel satisfied with student engagement
# 3            feel assured by evidence-based decisions
# 4   feel accomplished after successful course comp...
# 5                           feel motivated to improve
# 6                          feel informed and prepared
# 7                    feel responsive to student needs
# 8                   feel confident in decision-making
# 9                     feel accomplished and satisfied
# 10                     feel efficient and resourceful
# 11                       feel supported and connected
# 12                        feel focused and purposeful
# 13                    feel overwhelmed and frustrated
# 14                      feel adaptable and empathetic
#
#                                        Social Aspects  \
# 0                   be seen as an innovative educator
# 1              be perceived as responsive to feedback
# 2          be respected for pedagogical effectiveness
# 3      be recognized for data-driven teaching methods
# 4          be acknowledged for continuous improvement
# 5                    be seen as diligent and thorough
# 6     be perceived as data-driven and student-focused
# 7              be regarded as adaptive and responsive
# 8            be respected for making informed choices
# 9   be acknowledged for producing a comprehensive ...
# 10               be seen as pragmatic and resourceful
# 11    be viewed as collaborative and resource-sharing
# 12             be seen as goal-oriented and impactful
# 13             be perceived as compliant yet burdened
# 14     be recognized for inclusivity and adaptability
#
#                                                 Needs
# 0   minimize the time spent on assessing curriculu...
# 1           maximize the relevance of course material
# 2            increase the level of student engagement
# 3         decrease the uncertainty in decision-making
# 4   minimize the effort needed for future course r...
# 5   minimize time spent on reviewing existing mate...
# 6         maximize accuracy of student data collected
# 7   increase effectiveness of feedback collection ...
# 8     decrease uncertainty in decision-making process
# 9   minimize discrepancies between curriculum and ...
# 10                maximize use of available resources
# 11  minimize difficulty in accessing shared resources
# 12           maximize time spent on high-impact tasks
# 13      minimize complexity of bureaucratic processes
# 14           increase versatility of teaching methods

# %%
import json
import pandas as pd
from importlib import reload

import lib.categorize_job_steps as this
reload(this)

job_steps = analysis["Job Step"]

res = this.chain.invoke({"main_job":selected_main_job, "job_performers": selected_job_performers, "job_steps":job_steps})
res_dict = (json.loads(res.additional_kwargs['function_call']['arguments']))

job_steps_categorized = pd.DataFrame(res_dict['analysis'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[34], line 11
#       8 job_steps = analysis["Job Step"]
#      10 res = this.chain.invoke({"main_job":selected_main_job, "job_performers": selected_job_performers, "job_steps":job_steps})
# ---> 11 res_dict = (json.loads(res.additional_kwargs['function_call']['arguments']))
#      13 job_steps_categorized = pd.DataFrame(res_dict['analysis'])
#
# KeyError: 'function_call'

# %%
res
# Out:
# AIMessage(content='```json\n[\n    {\n        "Category": "Monitor",\n        "Job Step": "Review and assess existing curriculum"\n    },\n    {\n        "Category": "Modify",\n        "Job Step": "Collect feedback and integrate new findings"\n    },\n    {\n        "Category": "Execute",\n        "Job Step": "Implement and observe curriculum in the classroom"\n    },\n    {\n        "Category": "Modify",\n        "Job Step": "Make decisions based on data and experience"\n    },\n    {\n        "Category": "Modify",\n        "Job Step": "Review outcomes and plan for future improvements"\n    },\n    {\n        "Category": "Monitor",\n        "Job Step": "Review and assess current curriculum"\n    },\n    {\n        "Category": "Monitor",\n        "Job Step": "Gather data on student performance and feedback"\n    },\n    {\n        "Category": "Monitor",\n        "Job Step": "Collect feedback and monitor engagement after implementation"\n    },\n    {\n        "Category": "Modify",\n        "Job Step": "Make data-driven and student-centered decisions"\n    },\n    {\n        "Category": "Define",\n        "Job Step": "Finalize and align curriculum with standards and regulations"\n    },\n    {\n        "Category": "Prepare",\n        "Job Step": "Adapt existing resources when time is constrained"\n    },\n    {\n        "Category": "Locate",\n        "Job Step": "Access and utilize shared educational resources"\n    },\n    {\n        "Category": "Define",\n        "Job Step": "Prioritize tasks with direct impact on student learning"\n    },\n    {\n        "Category": "Prepare",\n        "Job Step": "Navigate educational bureaucracy and paperwork"\n    },\n    {\n        "Category": "Modify",\n        "Job Step": "Adapt teaching approach to diverse student needs"\n    }\n]\n```', response_metadata={'token_usage': {'completion_tokens': 381, 'prompt_tokens': 420, 'total_tokens': 801}, 'model_name': 'gpt-4-1106-preview', 'system_fingerprint': 'fp_99a5a401bb', 'finish_reason': 'stop', 'logprobs': None})

# %%
job_steps_categorized

# %%
analysis = pd.merge(analysis, job_steps_categorized[["Job Step", "Category"]], on='Job Step', how='outer')

# %%
analysis

# %%
custom_order = [
    'Define',
    'Locate',
    'Prepare',
    'Confirm',
    'Execute',
    'Monitor',
    'Modify',
    'Conclude'
]


# Create a Categorical data type with the custom order
category_dtype = pd.CategoricalDtype(categories=custom_order, ordered=True)

# Apply the custom order to the 'Job Step' column
analysis['Job Step'] = analysis['Job Step'].astype(category_dtype)

# Sort the DataFrame based on the 'Job Step' column
df = analysis.sort_values(by='Job Step')

df
# Out:
#                                        Quote and note Job Step  \
# 0   I begin by reviewing the existing curriculum a...      NaN
# 1   The previous step is to collect feedback from ...      NaN
# 2   After refining the curriculum, I implement it ...      NaN
# 3   Decisions are made based on a combination of s...      NaN
# 4   I wrap things up by reviewing the outcomes of ...      NaN
# 5   I start by reviewing the current curriculum, a...      NaN
# 6   The previous step is gathering data on student...      NaN
# 7   After implementing changes, I continue by coll...      NaN
# 8   My decisions are data-driven and student-cente...      NaN
# 9   I wrap things up by finalizing the curriculum,...      NaN
# 10  When time is limited, I may adapt existing res...      NaN
# 11  Accessing shared resources could be easier. A ...      NaN
# 12  I tend to avoid tasks that don't have a direct...      NaN
# 13  The most frustrating part is navigating bureau...      NaN
# 14  I adapt my approach when faced with varying le...      NaN
#
#                                     Emotional Aspects  \
# 0       feel excited about the potential improvements
# 1        feel confident in the curriculum's relevance
# 2              feel satisfied with student engagement
# 3            feel assured by evidence-based decisions
# 4   feel accomplished after successful course comp...
# 5                           feel motivated to improve
# 6                          feel informed and prepared
# 7                    feel responsive to student needs
# 8                   feel confident in decision-making
# 9                     feel accomplished and satisfied
# 10                     feel efficient and resourceful
# 11                       feel supported and connected
# 12                        feel focused and purposeful
# 13                    feel overwhelmed and frustrated
# 14                      feel adaptable and empathetic
#
#                                        Social Aspects  \
# 0                   be seen as an innovative educator
# 1              be perceived as responsive to feedback
# 2          be respected for pedagogical effectiveness
# 3      be recognized for data-driven teaching methods
# 4          be acknowledged for continuous improvement
# 5                    be seen as diligent and thorough
# 6     be perceived as data-driven and student-focused
# 7              be regarded as adaptive and responsive
# 8            be respected for making informed choices
# 9   be acknowledged for producing a comprehensive ...
# 10               be seen as pragmatic and resourceful
# 11    be viewed as collaborative and resource-sharing
# 12             be seen as goal-oriented and impactful
# 13             be perceived as compliant yet burdened
# 14     be recognized for inclusivity and adaptability
#
#                                                 Needs
# 0   minimize the time spent on assessing curriculu...
# 1           maximize the relevance of course material
# 2            increase the level of student engagement
# 3         decrease the uncertainty in decision-making
# 4   minimize the effort needed for future course r...
# 5   minimize time spent on reviewing existing mate...
# 6         maximize accuracy of student data collected
# 7   increase effectiveness of feedback collection ...
# 8     decrease uncertainty in decision-making process
# 9   minimize discrepancies between curriculum and ...
# 10                maximize use of available resources
# 11  minimize difficulty in accessing shared resources
# 12           maximize time spent on high-impact tasks
# 13      minimize complexity of bureaucratic processes
# 14           increase versatility of teaching methods

# %%
analysis['Job Step']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
# 5     NaN
# 6     NaN
# 7     NaN
# 8     NaN
# 9     NaN
# 10    NaN
# 11    NaN
# 12    NaN
# 13    NaN
# 14    NaN
# Name: Job Step, dtype: category
# Categories (8, object): ['Define' < 'Locate' < 'Prepare' < 'Confirm' < 'Execute' < 'Monitor' < 'Modify' < 'Conclude']
